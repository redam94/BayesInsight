# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from foottraffic.awb_model.models import model, variablemodels, priormodel, dataloading
import numpy as np
import pandas as pd
from einops import rearrange, reduce, repeat

# %%
mff = pd.DataFrame()
mff["Period"] = repeat(pd.Series(pd.date_range("2020-04-01", freq="W-MON", periods=156)).to_numpy(), "d -> (d g p v)", g=10, p=5, v=20)
mff["Geography"] = repeat(
  np.array(["US", "UK", "DE", "FR", "JP",
   "CA", "AU", "BR", "MX", "KR"]), 
  "g -> (d g p v)", d=156, p=5, v=20)
mff["Product"] = repeat(
  np.array(["Watches", "Phones", "Laptops", "Tablets", "Desktops"]),
  "p -> (d g p v)", d=156, g=10, v=20)
mff['VariableName'] = repeat(
  np.array(["Sales", "Price", "Promotion", "Stock", "Competition"] + [f"media_var_{i}" for i in range(15)]),
  "v -> (d g p v)", d=156, g=10, p=5)
mff['VariableValue'] = np.random.normal(size=mff.shape[0])
mff["Outlet"] = "Total"
mff["Campaign"] = "Total"
mff["Creative"] = "Total"
mff.head()
# Out:
#       Period Geography  Product VariableName  VariableValue Outlet Campaign  \
# 0 2020-04-06        US  Watches        Sales      -1.178103  Total    Total
# 1 2020-04-06        US  Watches        Price       0.123505  Total    Total
# 2 2020-04-06        US  Watches    Promotion      -0.858016  Total    Total
# 3 2020-04-06        US  Watches        Stock      -0.250310  Total    Total
# 4 2020-04-06        US  Watches  Competition      -0.701515  Total    Total
#
#   Creative
# 0    Total
# 1    Total
# 2    Total
# 3    Total
# 4    Total

# %%
mff.to_csv("mff.csv", index=False)

# %%
my_mff = dataloading.MFF.load_from_file("mff.csv")
my_mff.set_index_rows(['Geography', 'Product'])
my_mff.to_bundle("example_dataset")
# Out:
# /Users/mreda/miniconda3/envs/foottraffic/lib/python3.11/site-packages/pydantic/main.py:352: UserWarning: Pydantic serializer warnings:
#   Expected `tuple[literal['Geography','Period','Product','Outlet','Campaign','Creative'], ...]` but got `list` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_json(

# %%
my_mff.analytic_dataframe(indexed=True).head()
# Out:
#                                Competition_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                      -0.668955
#                    2020-04-13                      -0.958664
#                    2020-04-20                       0.577616
#                    2020-04-27                      -1.750890
#                    2020-05-04                       0.197452
#
#                                Price_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                 0.174888
#                    2020-04-13                 0.054043
#                    2020-04-20                 0.203846
#                    2020-04-27                -1.369900
#                    2020-05-04                 0.367659
#
#                                Promotion_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                     1.041951
#                    2020-04-13                     0.726187
#                    2020-04-20                    -1.076217
#                    2020-04-27                    -0.646932
#                    2020-05-04                     0.212854
#
#                                Sales_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                 0.051555
#                    2020-04-13                 1.153100
#                    2020-04-20                 0.791275
#                    2020-04-27                 0.174080
#                    2020-05-04                -0.680308
#
#                                Stock_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                 0.065232
#                    2020-04-13                -2.145637
#                    2020-04-20                -0.416459
#                    2020-04-27                 0.756465
#                    2020-05-04                 1.619176
#
#                                media_var_0_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       0.211632
#                    2020-04-13                      -1.452407
#                    2020-04-20                      -0.423842
#                    2020-04-27                      -0.250443
#                    2020-05-04                      -0.406937
#
#                                media_var_1_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                      -0.279096
#                    2020-04-13                      -0.105823
#                    2020-04-20                      -0.877859
#                    2020-04-27                      -0.087381
#                    2020-05-04                      -0.265654
#
#                                media_var_10_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                        0.656968
#                    2020-04-13                       -0.008716
#                    2020-04-20                        0.305064
#                    2020-04-27                        1.088403
#                    2020-05-04                        1.617760
#
#                                media_var_11_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       -0.730644
#                    2020-04-13                        0.526612
#                    2020-04-20                        0.230916
#                    2020-04-27                       -0.801312
#                    2020-05-04                        0.075905
#
#                                media_var_12_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                        0.549378
#                    2020-04-13                        0.906097
#                    2020-04-20                       -0.466518
#                    2020-04-27                       -1.606282
#                    2020-05-04                        1.287290
#
#                                media_var_13_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                        1.146531
#                    2020-04-13                       -1.879932
#                    2020-04-20                       -0.749242
#                    2020-04-27                        1.496944
#                    2020-05-04                       -1.638682
#
#                                media_var_14_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       -0.400975
#                    2020-04-13                       -1.924272
#                    2020-04-20                       -0.702007
#                    2020-04-27                       -1.768853
#                    2020-05-04                        0.080596
#
#                                media_var_2_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                      -0.367749
#                    2020-04-13                      -0.552653
#                    2020-04-20                       0.502513
#                    2020-04-27                       0.331107
#                    2020-05-04                      -0.038930
#
#                                media_var_3_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       0.452777
#                    2020-04-13                      -0.870905
#                    2020-04-20                      -0.158062
#                    2020-04-27                      -0.018591
#                    2020-05-04                       0.336604
#
#                                media_var_4_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       1.382348
#                    2020-04-13                      -0.467544
#                    2020-04-20                      -0.379298
#                    2020-04-27                      -0.750304
#                    2020-05-04                      -1.699432
#
#                                media_var_5_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       0.925085
#                    2020-04-13                       0.854776
#                    2020-04-20                      -0.540266
#                    2020-04-27                       1.347592
#                    2020-05-04                      -0.539523
#
#                                media_var_6_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                       1.509457
#                    2020-04-13                       1.029410
#                    2020-04-20                      -0.316385
#                    2020-04-27                      -0.155127
#                    2020-05-04                      -0.809915
#
#                                media_var_7_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                      -0.583835
#                    2020-04-13                      -2.138256
#                    2020-04-20                      -0.747077
#                    2020-04-27                       1.152588
#                    2020-05-04                       0.180295
#
#                                media_var_8_Total_Total_Total  \
# Geography Product  Period
# AU        Desktops 2020-04-06                      -0.430005
#                    2020-04-13                      -1.863064
#                    2020-04-20                       0.426128
#                    2020-04-27                      -0.508272
#                    2020-05-04                      -1.081435
#
#                                media_var_9_Total_Total_Total
# Geography Product  Period
# AU        Desktops 2020-04-06                      -0.342547
#                    2020-04-13                       0.259662
#                    2020-04-20                       1.745251
#                    2020-04-27                       0.469133
#                    2020-05-04                      -0.789428

# %%
model.FoottrafficModel.new_from_dataset("example_dataset")
# Out:
# /Users/mreda/miniconda3/envs/foottraffic/lib/python3.11/site-packages/pydantic/main.py:352: UserWarning: Pydantic serializer warnings:
#   Expected `tuple[literal['Geography','Period','Product','Outlet','Campaign','Creative'], ...]` but got `list` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_json(

# %%
my_model = model.FoottrafficModel.load("first model")

# %%
my_model.data.analytic_dataframe().head()
# Out:
#   Geography  Product     Period  Media 1_Outlet_Campaign_Creative  \
# 0    Canada  Jewelry 2021-12-06                          0.761563
# 1    Canada  Jewelry 2021-12-13                          0.632769
# 2    Canada  Jewelry 2021-12-20                         -1.822554
# 3    Canada  Jewelry 2021-12-27                          0.033166
# 4    Canada  Jewelry 2022-01-03                         -0.527984
#
#    Media 2_Outlet_Campaign_Creative
# 0                          1.195581
# 1                          0.884852
# 2                          0.779260
# 3                         -0.642591
# 4                         -0.680240

# %%
my_model.data.analytic_dataframe(indexed=True).head()
# Out:
#                               Media 1_Outlet_Campaign_Creative  \
# Geography Product Period
# Canada    Jewelry 2021-12-06                          0.761563
#                   2021-12-13                          0.632769
#                   2021-12-20                         -1.822554
#                   2021-12-27                          0.033166
#                   2022-01-03                         -0.527984
#
#                               Media 2_Outlet_Campaign_Creative
# Geography Product Period
# Canada    Jewelry 2021-12-06                          1.195581
#                   2021-12-13                          0.884852
#                   2021-12-20                          0.779260
#                   2021-12-27                         -0.642591
#                   2022-01-03                         -0.680240

# %%
my_model.fit()
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [x]
# d:\MattReda\miniforge\envs\foottraffic\Lib\site-packages\rich\live.py:231: UserWarning: install "ipywidgets" for
# Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Sampling 4 chains for 1_000 tune and 1_000 draw iterations (4_000 + 4_000 draws total) took 33 seconds.

# %%
my_model.save('first model aug 2')
# Out:
# d:\MattReda\miniforge\envs\foottraffic\Lib\site-packages\pydantic\main.py:415: UserWarning: Pydantic serializer warnings:
#   Expected `tuple[literal['Geography','Period','Product','Outlet','Campaign','Creative'], ...]` but got `list` - serialized value may not be as expected
#   return self.__pydantic_serializer__.to_json(

# %%
my_

# %%
my_model.predict()

# %%
my_model.trace_plot()

# %%
my_model.save_outputs()

# %%
my_model.summary()
